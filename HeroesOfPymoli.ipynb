# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

purchase_data.head(10)
# Out:
#    Purchase ID             SN  Age                 Gender  Item ID  \
# 0            0        Lisim78   20                   Male      108
# 1            1    Lisovynya38   40                   Male      143
# 2            2     Ithergue48   24                   Male       92
# 3            3  Chamassasya86   24                   Male      100
# 4            4      Iskosia90   23                   Male      131
# 5            5        Yalae81   22                   Male       81
# 6            6      Itheria73   36                   Male      169
# 7            7    Iskjaskst81   20                   Male      162
# 8            8      Undjask33   22                   Male       21
# 9            9    Chanosian48   35  Other / Non-Disclosed      136
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# ...

# %%
# I dont like SN so I changed it to Players Name
purchase_data.rename(columns={'SN':'Player Name'}, 
          inplace=True)


#I am verifying that the new column name is Players name
purchase_data.columns


# counting the total number of unique players in the dataframe
players= len(purchase_data['Player Name'].unique())

players

# %%
Num = len(purchase_data['Item Name'].unique())
Num

priceavg = purchase_data['Price'].mean()
priceavg

# finding totale revenue by summing all the prices
priceavg1 = purchase_data['Price'].sum()
priceavg1

purchasetot = len(purchase_data['Purchase ID'])
purchasetot
# Out:
# 179

# %%
# Summary Stats unfortunatley I couldnt format the cells to sow accurate symbols

Purchasing_Analysis_Total= pd.DataFrame({"Number of Unique Items":[Num],"Average Purchase Price in dollars":[priceavg],
                                         "Total Number of Purchases": [purchasetot], "Total Revenue in dollars":[priceavg1],
                                         "Player Count": [players] })
Purchasing_Analysis_Total
# Out:
#    Number of Unique Items  Average Purchase Price in dollars  \
# 0                     179                           3.050987
#
#    Total Number of Purchases  Total Revenue in dollars  Player Count
# 0                        780                   2379.77           576

# %%
# creating new datasets/dataframes by gender
Female_purchasedata = purchase_data.loc[purchase_data['Gender'] == 'Female']
Female_purchasedata


male_purchasedata = purchase_data.loc[purchase_data['Gender'] == 'Male']
male_purchasedata
# Out:
# 113

# %%
# Group counts based on Gender
fplayers= len(Female_purchasedata['Player Name'].unique())

fplayers

mplayers= len(male_purchasedata['Player Name'].unique())

mplayers

nogender= players-mplayers-fplayers
nogender
# Out:
# 81

# %%
#player percentages and output data frame
Maleper= (mplayers/players)*100
Femaleper= (fplayers/players)*100
nogenderper= (nogender/players)*100

Demographics_Gender= pd.DataFrame({"Gender": ['Male', 'Female' , 'Other/Non-Disclosed'],
                                         "Percentage Of Players in %": [Maleper,Femaleper,nogenderper],
                                         "Player Count":[mplayers,fplayers,nogender]})

Demographics_Gender
# Out:
#                 Gender  Percentage Of Players in %  Player Count
# 0                 Male                   84.027778           484
# 1               Female                   14.062500            81
# 2  Other/Non-Disclosed                    1.909722            11

# %%
# Male and Female purchase counts
purcountf = len(Female_purchasedata['Purchase ID'].unique())

purcountm = len(male_purchasedata['Purchase ID'].unique())

purcountno = len(nogender_purchasedata1['Purchase ID'].unique())

# male and female average purchase price
priceavgf = Female_purchasedata['Price'].mean()
priceavgf

priceavgm = male_purchasedata['Price'].mean()
priceavgm

priceavgno = nogender_purchasedata1['Price'].mean()
priceavgno
# Male and female total purchase value
totpurchasef = Female_purchasedata['Price'].sum()
totpurchasef

totpurchasem = male_purchasedata['Price'].sum()
totpurchasem

totpurchaseno = nogender_purchasedata1['Price'].sum() 


Purchasing_Analysis_Gender1= pd.DataFrame({"Gender": ['Male', 'Female' , 'Other/Non-Disclosed'],
                                         "Purchase Count": [purcountm,purcountf,purcountno],
                                         "Average Purchase Price in Dollars":[priceavgm,priceavgf,priceavgno],
                                          "Total Purchase Value in Dollars":[totpurchasem,totpurchasef,totpurchaseno]})

Purchasing_Analysis_Gender1
# Out:
#                 Gender  Purchase Count  Average Purchase Price in Dollars  \
# 0                 Male             652                           3.017853
# 1               Female             113                           3.203009
# 2  Other/Non-Disclosed              15                           3.346000
#
#    Total Purchase Value in Dollars
# 0                          1967.64
# 1                           361.94
# 2                            50.19

# %%
# used this to extract data of the no Gender or non disclosed category of Gender

nogender_purchasedata = purchase_data.loc[purchase_data['Gender'] != 'Female'] 
nogender_purchasedata

nogender_purchasedata1 = nogender_purchasedata.loc[purchase_data['Gender'] != 'Male']
nogender_purchasedata1
# Out:
#      Purchase ID             SN  Age Gender  Item ID  \
# 0              0        Lisim78   20   Male      108
# 1              1    Lisovynya38   40   Male      143
# 2              2     Ithergue48   24   Male       92
# 3              3  Chamassasya86   24   Male      100
# 4              4      Iskosia90   23   Male      131
# ..           ...            ...  ...    ...      ...
# 774          774     Jiskjask80   11   Male       92
# 776          776         Iral74   21   Male      164
# 777          777     Yathecal72   20   Male       67
# 778          778        Sisur91    7   Male       92
# 779          779      Ennrian78   24   Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
nogender_purchasedata1 = nogender_purchasedata.loc[purchase_data['Gender'] != 'Male']
nogender_purchasedata1
# Out:
#      Purchase ID            SN  Age                 Gender  Item ID  \
# 9              9   Chanosian48   35  Other / Non-Disclosed      136
# 22            22  Siarithria38   38  Other / Non-Disclosed       24
# 82            82    Haerithp41   16  Other / Non-Disclosed      160
# 111          111      Sundim98   21  Other / Non-Disclosed       41
# 228          228   Jiskirran77   20  Other / Non-Disclosed       80
# 237          237     Idairin51   20  Other / Non-Disclosed       16
# 242          242     Eodaisu60   16  Other / Non-Disclosed       39
# 291          291     Idairin51   20  Other / Non-Disclosed       35
# 350          350     Rairith81   15  Other / Non-Disclosed       34
# 401          401      Lirtim36   15  Other / Non-Disclosed       46
# 484          484   Chanosian48   35  Other / Non-Disclosed       39
# 549          549    Maluncil97   25  Other / Non-Disclosed      146
# 629          629    Maluncil97   25  Other / Non-Disclosed      107
# ...

# %%
purchase_data.head()
# Out:
#      Purchase ID             SN  Age                 Gender  Item ID  \
# 0              0        Lisim78   20                   Male      108
# 1              1    Lisovynya38   40                   Male      143
# 2              2     Ithergue48   24                   Male       92
# 3              3  Chamassasya86   24                   Male      100
# 4              4      Iskosia90   23                   Male      131
# 5              5        Yalae81   22                   Male       81
# 6              6      Itheria73   36                   Male      169
# 7              7    Iskjaskst81   20                   Male      162
# 8              8      Undjask33   22                   Male       21
# 9              9    Chanosian48   35  Other / Non-Disclosed      136
# 14            14    Saesrideu94   35                   Male      165
# 16            16      Lisirra25   20                   Male       40
# 19            19      Chamalo71   30                   Male       89
# ...

# %%
# Creating Bins for age demogrphics
bins = [0,10,15,20,25,30,35,40,200]
age_groups = ['Under 10', '10 - 14', '15 - 19', '20 - 24', '25 - 29', '30 - 34', '35 - 39', 'Over 40']

# %%
purchase_data["Age groups"] = pd.cut(purchase_data["Age"], bins, labels=age_groups, include_lowest=True)
#purchase_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-126-f39a1daf91b6> in <module>
# ----> 1 purchase_data["Age groups"] = pd.cut(purchase_data["Age"], bins, labels=age_groups, include_lowest=True)
#       2 purchase_data
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     273             raise ValueError("bins must increase monotonically.")
#     274
# --> 275     fac, bins = _bins_to_cuts(
#     276         x,
#     277         bins,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     407
#     408     side = "left" if right else "right"
# --> 409     ids = ensure_int64(bins.searchsorted(x, side=side))
#     410
# ...

# %%
purchase_data = purchase_data.groupby("Age groups")
#purchase_data.max()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-12d4aed35ecb> in <module>
# ----> 1 purchase_data = purchase_data.groupby("Age groups")
#       2 purchase_data.max()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'

# %%
purchase_data.head(10)
# Out:
#      Purchase ID             SN  Age Gender  Item ID  \
# 0              0        Lisim78   20   Male      108
# 1              1    Lisovynya38   40   Male      143
# 2              2     Ithergue48   24   Male       92
# 3              3  Chamassasya86   24   Male      100
# 4              4      Iskosia90   23   Male      131
# ..           ...            ...  ...    ...      ...
# 477          477     Mindossa76   41   Male      173
# 557          557     Frichaya88   42   Male        8
# 674          674        Aeral68   43   Male       77
# 728          728   Chanosiaya39   44   Male       93
# 761          761        Assim27   45   Male       17
#
#                                      Item Name  Price Age groups
# 0    Extraction, Quickblade Of Trembling Hands   3.53    15 - 19
# 1                            Frenzied Scimitar   1.56    35 - 39
# 2                                 Final Critic   4.88    20 - 24
# 3                                  Blindscythe   3.27    20 - 24
# ...

# %%
# Male and Female purchase counts
purcountf = len(Female_purchasedata['Purchase ID'].unique())

purcountm = len(male_purchasedata['Purchase ID'].unique())

purcountno = len(nogender_purchasedata1['Purchase ID'].unique())

# male and female average purchase price
priceavgf = Female_purchasedata['Price'].mean()
priceavgf

priceavgm = male_purchasedata['Price'].mean()
priceavgm

priceavgno = nogender_purchasedata1['Price'].mean()
priceavgno
# Male and female total purchase value
totpurchasef = Female_purchasedata['Price'].sum()
totpurchasef

totpurchasem = male_purchasedata['Price'].sum()
totpurchasem

totpurchaseno = nogender_purchasedata1['Price'].sum() 


Purchasing_Analysis_Gender1= pd.DataFrame({"Gender": ['Male', 'Female' , 'Other/Non-Disclosed'],
                                         "Purchase Count": [purcountm,purcountf,purcountno],
                                         "Average Purchase Price in Dollars":[priceavgm,priceavgf,priceavgno],
                                          "Total Purchase Value in Dollars":[totpurchasem,totpurchasef,totpurchaseno]})

Purchasing_Analysis_Gender1
# Out:
#                 Gender  Purchase Count  Average Purchase Price in Dollars  \
# 0                 Male             652                           3.017853
# 1               Female             113                           3.203009
# 2  Other/Non-Disclosed              15                           3.346000
#
#    Total Purchase Value in Dollars
# 0                          1967.64
# 1                           361.94
# 2                            50.19
